# %%
import numpy as np

# %% [markdown]
# Importando dados da URL

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/numpy/dados/apples_ts.csv'
dado = np.loadtxt(url, delimiter=',', usecols=np.arange(1, 88, 1))

# %% [markdown]
# Importando arquivo

# %%
np.loadtxt('apples_ts.csv', delimiter=',', usecols=np.arange(1, 88, 1))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-9312b9aa84aa> in <cell line: 1>()
# ----> 1 np.loadtxt('apples_ts.csv', delimiter=',', usecols=np.arange(1, 88, 1))
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1371         delimiter = delimiter.decode('latin1')
#    1372
# -> 1373     arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1374                 converters=converters, skiplines=skiprows, usecols=usecols,
#    1375                 unpack=unpack, ndmin=ndmin, encoding=encoding,
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/npyio.py in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#     990             fname = os.fspath(fname)
#     991         if isinstance(fname, str):
# --> 992             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     993             if encoding is None:
#     994                 encoding = getattr(fh, 'encoding', 'latin1')
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     191
#     192     ds = DataSource(destpath)
# --> 193     return ds.open(path, mode, encoding=encoding, newline=newline)
#     194
#     195
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     531                                       encoding=encoding, newline=newline)
#     532         else:
# --> 533             raise FileNotFoundError(f"{path} not found.")
#     534
#     535
#
# FileNotFoundError: apples_ts.csv not found.

# %%
dado.ndim
# Out:
# 2

# %%
dado.size
# Out:
# 522

# %%
dado.shape
# Out:
# (6, 87)

# %%
dado_transposto = dado.T

# %%
datas = dado_transposto[:,0]

# %%
precos = dado_transposto[:,1:6]

# %%
import matplotlib.pyplot as plt

# %%
datas = np.arange(1, 88, 1)

# %%
plt.plot(datas, precos[:,0])

# %%
Moscow = precos[:,0]
Kaliningrad = precos[:,1]
Petersburg = precos[:,2]
Kransnodar = precos[:,3]
Ekaterinburg = precos[:,4]

# %%
Moscow_ano1 = Moscow[0:12]
Moscow_ano2 = Moscow[12:24]
Moscow_ano3 = Moscow[24:36]
Moscow_ano4 = Moscow[36:48]

# %%
plt.plot(datas, Moscow)

# %% [markdown]
# **y = ax + b** | a = coeficiente angular e b = coeficiente linear

# %%
x = datas

# %%
y = 2*x+80

# %%
plt.plot(datas, Moscow)
plt.plot(x, y)

# %%
np.sqrt(np.sum(np.power(Moscow-y, 2)))
# Out:
# 749.2329171225728

# %%
y = 0.52*x + 80

# %%
plt.plot(datas, Moscow)
plt.plot(x, y)

# %%
np.sqrt(np.sum(np.power(Moscow-y, 2)))
# Out:
# 110.48504740461489

# %%
np.linalg.norm(Moscow-y)
# Out:
# 110.48504740461489

# %%
Y = Moscow
X = datas
n = np.size(Moscow)

# %% [markdown]
# Calculando o coeficiente angular

# %%
X**2
# Out:
# array([   1,    4,    9,   16,   25,   36,   49,   64,   81,  100,  121,
#         144,  169,  196,  225,  256,  289,  324,  361,  400,  441,  484,
#         529,  576,  625,  676,  729,  784,  841,  900,  961, 1024, 1089,
#        1156, 1225, 1296, 1369, 1444, 1521, 1600, 1681, 1764, 1849, 1936,
#        2025, 2116, 2209, 2304, 2401, 2500, 2601, 2704, 2809, 2916, 3025,
#        3136, 3249, 3364, 3481, 3600, 3721, 3844, 3969, 4096, 4225, 4356,
#        4489, 4624, 4761, 4900, 5041, 5184, 5329, 5476, 5625, 5776, 5929,
#        6084, 6241, 6400, 6561, 6724, 6889, 7056, 7225, 7396, 7569])

# %%
a = (n*np.sum(X*Y) - np.sum(X) * np.sum(Y)) / (n*np.sum(X**2) - np.sum(X)**2)

# %% [markdown]
# Calculando o coeficiente linear

# %%
b = np.mean(Y) - a*np.mean(X)

# %%
y = a*X+b

# %%
np.linalg.norm(Moscow-y)
# Out:
# 101.7969539992751

# %%
plt.plot(datas, Moscow)
plt.plot(x, y)
plt.plot(41.5, 41.5*a+b, '*r')
plt.plot(100, 100*a+b, '*r')

# %%
np.random.randint(low=40, high=100, size=100)
# Out:
# array([80, 71, 47, 82, 92, 74, 87, 76, 67, 93, 83, 84, 55, 90, 46, 83, 71,
#        87, 96, 43, 55, 48, 88, 92, 72, 73, 72, 46, 44, 65, 64, 40, 64, 72,
#        87, 48, 48, 60, 48, 96, 84, 69, 52, 64, 88, 80, 77, 41, 54, 92, 64,
#        70, 90, 48, 83, 43, 47, 89, 76, 87, 81, 55, 82, 52, 92, 77, 55, 51,
#        91, 78, 65, 81, 93, 40, 69, 52, 89, 72, 48, 85, 43, 48, 64, 80, 64,
#        66, 59, 47, 82, 66, 61, 40, 41, 95, 57, 58, 89, 50, 96, 62])

# %%
coef_angulares = np.random.uniform(low=0.10, high=0.90, size=100)

# %%
norma2 = np.array([])
for i in range(100):
  norma2 = np.append(norma2, np.linalg.norm(Moscow-(coef_angulares[i]*X+b)))

# %%
norma2
# Out:
# array([119.26111411, 148.68650581, 102.95008725, 106.65759935,
#        124.42270211, 136.30336143, 101.92088826, 121.38238703,
#        187.8694113 , 107.49173054, 107.29521828, 239.33254419,
#        107.47445523, 148.34499125, 129.03279267, 200.63593098,
#        177.27303838, 103.6879542 , 169.74686252, 132.81186234,
#        108.23712798, 179.79404614, 101.89028587, 129.80547089,
#        101.89080688, 202.03780431, 187.92960712, 104.91109456,
#        102.86323989, 144.01344372, 184.5862494 , 194.4561719 ,
#        121.79920957, 117.02882714, 115.68997249, 181.87135048,
#        227.96325043, 221.46243254, 116.42917783, 123.14940418,
#        240.55307347, 224.90049232, 121.59747147, 119.73425539,
#        227.73529643, 117.18867393, 193.21037266, 179.10043739,
#        102.68838993, 117.26307703, 105.64166208, 181.55299025,
#        102.18342947, 131.6378387 , 126.86050959, 145.52266947,
#        105.06679332, 117.58283651, 172.24531924, 170.45786158,
#        165.96819731, 158.49377313, 111.71699159, 114.40234357,
#        106.4038283 , 159.68435785, 104.11409844, 102.64079849,
#        166.10949073, 156.12859033, 119.14181509, 105.15272407,
#        192.91029084, 137.61611486, 126.56147233, 154.70705691,
#        121.30097221, 153.66439789, 241.14447855, 173.80561126,
#        143.18324829, 177.33738198, 165.17416292, 150.61406501,
#        104.14033932, 138.48397654, 179.59813548, 201.59280206,
#        120.76019979, 136.10665831, 120.9613751 , 174.14697314,
#        101.80470941, 156.20920446, 105.44627527, 186.81280454,
#        132.98655721, 103.11261647, 209.21519594, 102.97824805])

# %%
coef_angulares[1]
# Out:
# 0.3084867741980126

# %%
np.random.uniform(low=0.10, high=0.90, size=100)
# Out:
# array([0.34120147, 0.61719355, 0.40451465, 0.6931383 , 0.32598161,
#        0.4142114 , 0.17113123, 0.62335506, 0.22480096, 0.40025881,
#        0.77075045, 0.12185746, 0.77147187, 0.6511091 , 0.84744162,
#        0.27275331, 0.84579076, 0.56705293, 0.40011095, 0.36160899,
#        0.66230521, 0.7580477 , 0.74854054, 0.26769615, 0.64479021,
#        0.41234908, 0.62888053, 0.75293108, 0.41993797, 0.35154848,
#        0.3010432 , 0.36377369, 0.1175342 , 0.30581353, 0.69716263,
#        0.15285564, 0.33174714, 0.29882193, 0.42298416, 0.57156262,
#        0.17640818, 0.66214519, 0.49045519, 0.75430385, 0.84912829,
#        0.13853887, 0.48426369, 0.35214051, 0.48900942, 0.66783918,
#        0.37929888, 0.72605645, 0.68910586, 0.17714908, 0.64744599,
#        0.74468631, 0.81604006, 0.19376706, 0.73235726, 0.1880548 ,
#        0.81454554, 0.8103094 , 0.74879166, 0.14478278, 0.872477  ,
#        0.19596073, 0.43232338, 0.25499248, 0.66963997, 0.6007225 ,
#        0.1174804 , 0.1977272 , 0.53753737, 0.83301112, 0.35875905,
#        0.38240269, 0.78875307, 0.54548929, 0.19423333, 0.30878001,
#        0.54183359, 0.56866425, 0.72820664, 0.57792153, 0.27572112,
#        0.70231384, 0.43914992, 0.35512873, 0.22335651, 0.66369004,
#        0.79190051, 0.82418941, 0.27766865, 0.2568196 , 0.35249735,
#        0.17969486, 0.67372025, 0.44322304, 0.78557807, 0.84620312])

# %%
np.random.seed(16)
np.random.uniform(low=0.10, high=0.90, size=100)
# Out:
# array([0.27863286, 0.51853067, 0.54056117, 0.13648156, 0.38858307,
#        0.27846475, 0.65098093, 0.23098514, 0.15625989, 0.85280869,
#        0.5509451 , 0.16239387, 0.67811241, 0.22676174, 0.30022505,
#        0.3347898 , 0.65728857, 0.47141127, 0.27204971, 0.45746101,
#        0.196703  , 0.83414961, 0.55315706, 0.47761545, 0.35165314,
#        0.13457258, 0.70195593, 0.53461524, 0.71375234, 0.73235901,
#        0.1577771 , 0.62777267, 0.14263947, 0.64801956, 0.45468077,
#        0.47439692, 0.62884747, 0.65197331, 0.31066359, 0.10918315,
#        0.71703556, 0.75291386, 0.21171328, 0.5624054 , 0.37253942,
#        0.28577239, 0.258915  , 0.31719262, 0.88148221, 0.27234318,
#        0.38512593, 0.11471996, 0.59343222, 0.28432431, 0.69388139,
#        0.56740017, 0.43608284, 0.66740227, 0.87763642, 0.74803129,
#        0.44452414, 0.86618288, 0.13820648, 0.68622544, 0.64053316,
#        0.52160413, 0.55358996, 0.6783562 , 0.64608268, 0.73625014,
#        0.19027642, 0.25933011, 0.67705538, 0.41509386, 0.37134832,
#        0.22275655, 0.18045921, 0.42579769, 0.56633237, 0.69257642,
#        0.79628867, 0.87322093, 0.46445188, 0.4203384 , 0.3391517 ,
#        0.76268805, 0.82787294, 0.71290934, 0.15465183, 0.58482122,
#        0.85137291, 0.18171413, 0.88203161, 0.38535098, 0.62334973,
#        0.19822857, 0.86908175, 0.62094514, 0.84934225, 0.82706184])

# %%
np.random.seed(84)
coef_angulares = np.random.uniform(low=0.10, high=0.90, size=100)
norma2 = np.array([])
for i in range(100):
  norma2 = np.append(norma2, np.linalg.norm(Moscow-(coef_angulares[i]*X+b)))

# %%
norma2
# Out:
# array([173.90151233, 103.45241986, 121.75367289, 128.97173036,
#        238.69504078, 149.16590195, 137.73123242, 118.54419212,
#        101.79720981, 149.04689147, 112.80225228, 105.8049351 ,
#        230.82444742, 111.69709582, 134.56525603, 110.93209631,
#        204.12484401, 196.82117307, 221.88687726, 156.13691054,
#        125.51272174, 136.46474504, 165.39506278, 240.68784732,
#        104.52254473, 188.75637903, 131.2292927 , 128.94885341,
#        234.70773582, 147.01799832, 113.7418054 , 116.94496221,
#        109.58257043, 107.09546548, 145.00728041, 182.83818792,
#        140.95017242, 106.12371866, 107.0915778 , 132.45242448,
#        144.8736358 , 143.54772697, 240.23793834, 113.74604121,
#        116.01191029, 152.02977343, 174.72333708, 141.8068161 ,
#        101.93467119, 103.01538109, 169.59787792, 128.13083711,
#        105.06648948, 101.83421597, 102.53716362, 113.63850533,
#        219.96993004, 117.37921502, 182.70217805, 146.69612581,
#        178.64742004, 132.25425967, 109.74998636, 186.49825034,
#        104.98272763, 133.73791912, 182.82613374, 235.49081018,
#        179.79275527, 228.72013359, 184.2584889 , 114.02435937,
#        124.95415977, 187.42082714, 105.18421164, 102.1005486 ,
#        135.72717949, 107.19212075, 114.07766563, 225.76351056,
#        103.96340568, 118.21130391, 109.96158846, 181.54233309,
#        114.09828878, 118.61778913, 224.37792949, 153.50523694,
#        185.44994519, 117.35423938, 151.19534147, 118.44720795,
#        112.26379208, 104.60483872, 123.8587347 , 111.40038324,
#        102.05294074, 150.97459646, 108.76787533, 107.97542886])

# %%
coef_angulares
# Out:
# array([0.13683279, 0.39619385, 0.29385461, 0.602784  , 0.89208805,
#        0.20447044, 0.23887133, 0.30665125, 0.43471917, 0.20481511,
#        0.3323601 , 0.49624488, 0.87360345, 0.33791189, 0.62144155,
#        0.52849032, 0.8096211 , 0.7916786 , 0.85242626, 0.18466651,
#        0.59057786, 0.24287265, 0.15934165, 0.89674619, 0.38501918,
#        0.77157959, 0.61045713, 0.2676991 , 0.88274155, 0.21072909,
#        0.54257849, 0.3133875 , 0.34935345, 0.36479868, 0.21666475,
#        0.75660734, 0.22889395, 0.4986747 , 0.36482516, 0.25587381,
#        0.21706205, 0.64938079, 0.89569528, 0.32780566, 0.55295355,
#        0.19624604, 0.13469036, 0.22628157, 0.44641143, 0.40177235,
#        0.1481411 , 0.59986997, 0.49023732, 0.4293729 , 0.46122788,
#        0.54208756, 0.84785549, 0.31153122, 0.11414346, 0.65873013,
#        0.74587422, 0.61387426, 0.52200325, 0.76589084, 0.38088747,
#        0.25165091, 0.11382762, 0.88457997, 0.74881915, 0.86863621,
#        0.11018484, 0.32649201, 0.28185578, 0.10218576, 0.37916895,
#        0.45185191, 0.24522431, 0.50626125, 0.32624184, 0.86163791,
#        0.4798819 , 0.30803145, 0.34720986, 0.11710349, 0.32614518,
#        0.30634758, 0.85835026, 0.67834579, 0.76324004, 0.55876684,
#        0.19862885, 0.56335202, 0.53537079, 0.48614717, 0.58451562,
#        0.53095673, 0.45048903, 0.67114321, 0.35412587, 0.35901695])

# %%
dados = np.column_stack([norma2, coef_angulares])

# %%
dados.shape
# Out:
# (100, 2)

# %%
np.savetxt('dados.csv', dados, delimiter=',')

# %% [markdown]
# Usando o arquivo Orange vs Grapefruit

# %%
url = 'https://raw.githubusercontent.com/allanspadini/numpy/dados/citrus.csv'
dado1 = np.loadtxt(url, delimiter=',', skiprows=1, usecols=np.arange(1, 6, 1))

# %%
Y = peso_laranja
X = diametro_laranja
n = np.size(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-58e093d068b3> in <cell line: 1>()
# ----> 1 Y = peso_laranja
#       2 X = diametro_laranja
#       3 n = np.size(X)
#
# NameError: name 'peso_laranja' is not defined

# %%
a = (n*np.sum(X*Y) - np.sum(X) * np.sum(Y)) / (n*np.sum(X**2) - np.sum(X)**2)
b = np.mean(Y) - a*np.mean(X)
plt.plot(x, y)
plt.plot(5, 5*a+b, '*r')

# %%
norma = np.array([])
np.random.seed(84)
coef_angulares = np.random.uniform(low=0.0,high=30.0,size=100)

for i in range(100):
  norma = np.append(norma,np.linalg.norm(Y- (coef_angulares[i]*X+b)))

# %%
norma
# Out:
# array([  458.48561627,  5044.07319368,  3231.14877721,  8704.51903203,
#        13830.90666005,  1648.7593633 ,  2257.51063601,  3457.80613297,
#         5726.63812919,  1654.85556588,  3913.20504333,  6816.75876142,
#        13503.35971539,  4011.55298664,  9035.11801734,  7388.10488202,
#        12369.59660137, 12051.65771496, 13128.10052908,  1298.67441044,
#         8488.23531937,  2328.34600968,   852.0128023 , 13913.4490082 ,
#         4846.09457126, 11695.50663259,  8840.48144413,  2767.92887868,
#        13665.2867579 ,  1759.46744389,  7637.73117341,  3577.12585869,
#         4214.24076305,  4487.86273877,  1864.48394655, 11430.2013016 ,
#         2080.90179234,  6859.81157658,  4488.33200207,  2558.53246542,
#         1871.51388292,  9530.18521904, 13894.82687062,  3832.52608513,
#         7821.56633876,  1503.32395521,   421.55246286,  2034.6657176 ,
#         5933.79905939,  5142.90704711,   655.38450158,  8652.88456883,
#         6710.31401821,  5631.91475338,  6196.31674923,  7629.03242079,
#        13047.10678458,  3544.24499665,   111.28990073,  9695.85074736,
#        11240.012999  ,  8901.03056129,  7273.16202348, 11594.70301144,
#         4772.89496587,  2483.76156322,   109.14814868, 13697.86343465,
#        11292.19643857, 13415.34037034,   104.8632037 ,  3809.25570035,
#         3018.63651685,   195.51222629,  4742.44907424,  6030.19291851,
#         2369.97942347,  6994.23445887,  3804.82431457, 13291.33064026,
#         6526.83261922,  3482.25344398,  4176.26655571,   140.90788418,
#         3803.1120707 ,  3452.42732651, 13233.07355391, 10043.43126975,
#        11547.73144435,  7924.57199962,  1545.45429642,  8005.81709294,
#         7510.01883373,  6637.84305413,  8380.81733125,  7431.80682169,
#         6006.04552368,  9915.80474782,  4298.78629477,  4385.43477519])

# %%
coef_angulares
# Out:
# array([ 1.38122981, 11.10726948,  7.26954802, 18.85440015, 29.7033018 ,
#         3.91764148,  5.2076749 ,  7.74942173, 12.551969  ,  3.9305668 ,
#         8.71350376, 14.85918284, 29.01012944,  8.92169589, 19.55405809,
#        16.06838693, 26.61079143, 25.93794743, 28.21598469,  3.17499416,
#        18.39666959,  5.35772433,  2.22531178, 29.87798219, 10.68821932,
#        25.18423466, 19.14214247,  6.2887161 , 29.35280822,  4.15234091,
#        16.59669329,  8.00203135,  9.35075423,  9.92995032,  4.37492812,
#        24.62277514,  4.83352329, 14.95030108,  9.93094363,  5.84526794,
#         4.38982698, 20.60177977, 29.83857306,  8.54271236, 16.98575806,
#         3.60922643,  1.30088839,  4.73555879, 12.99042874, 11.31646296,
#         1.80529112, 18.74512405, 14.63389951, 12.35148368, 13.54604561,
#        16.5782834 , 28.04458097,  7.93242059,  0.53037966, 20.95237995,
#        24.22028342, 19.27028464, 15.82512199, 24.97090641, 10.53327999,
#         5.68690898,  0.51853556, 29.42174872, 24.33071825, 28.82385803,
#         0.3819315 ,  8.4934502 ,  6.8195916 ,  0.0819661 , 10.4688358 ,
#        13.19444647,  5.44591159, 15.23479681,  8.48406917, 28.56142166,
#        14.24557119,  7.80117928,  9.27036974,  0.64138088,  8.48044443,
#         7.73803418, 28.43813469, 21.68796718, 24.87150158, 17.20375632,
#         3.69858194, 17.37570081, 16.32640469, 14.48051899, 18.16933564,
#        16.16087747, 13.14333856, 21.41787055,  9.52972023,  9.71313571])
